# %% [markdown]
# <a href="https://colab.research.google.com/github/agawronski/word-embeddings/blob/main/20211114_2_hierarchical_patterns_topics_temporal_direction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic

# %%
from sklearn.linear_model import LinearRegression
from bertopic import BERTopic
import pandas as pd

# %%
data = pd.read_csv('https://word-emeddings.s3.us-west-2.amazonaws.com/20211107_main_article_dataframe_small.csv')
data.datePublished = pd.to_datetime(data.datePublished)

# %%
data.head()
# Out:
#                                             abstract  ... datePublished
# 0  <em>Waldsterben</em>. We are familiar with tha...  ...    2017-01-01
# 1                                                NaN  ...    2014-01-01
# 2                                                NaN  ...    2004-01-01
# 3  In 2012 I stood on the fourth floor of the Shi...  ...    2016-01-01
# 4  A clean energy transition² is an increasingly ...  ...    2019-11-01
#
# [5 rows x 3 columns]

# %%
# topic modeling
topic_model = BERTopic(verbose=True)
topics, probs = topic_model.fit_transform(data.fullText)

freq = topic_model.get_topic_info()
# Out:
# Batches:   0%|          | 0/44 [00:00<?, ?it/s]
# 2021-11-15 05:13:50,651 - BERTopic - Transformed documents to Embeddings
# 2021-11-15 05:13:58,598 - BERTopic - Reduced dimensionality with UMAP
# 2021-11-15 05:13:58,673 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
topic_model.get_topics()
# Out:
# {-1: [('on', 0.011824509618097969),
#   ('with', 0.010827350165348103),
#   ('to', 0.01081259251370511),
#   ('are', 0.010236746026480507),
#   ('by', 0.010210788726260574),
#   ('be', 0.009917633479678148),
#   ('has', 0.008081524897607677),
#   ('at', 0.007556283509579183),
#   ('their', 0.006872936439821583),
#   ('development', 0.006107898383142128)],
#  0: [('energy', 0.012513402702892142),
#   ('climate', 0.011789516429669801),
#   ('in', 0.011478808959473261),
#   ('development', 0.010070831860499284),
#   ('change', 0.00892103806765539),
#   ('emissions', 0.0072180398013768415),
#   ('sustainable', 0.007132099633421098),
#   ('environmental', 0.007077897919185383),
#   ('population', 0.006683758100908108),
#   ('index', 0.006589487418612333)],
#  1: [('women', 0.018660986364903438),
#   ('her', 0.016025139331659517),
#   ('she', 0.013422067118618392),
#   ('we', 0.01272258077676623),
#   ('with', 0.011235948361112712),
#   ('at', 0.010917987212941196),
#   ('my', 0.009802237168544238),
#   ('womens', 0.009653754829825112),
#   ('be', 0.009166702637876117),
#   ('our', 0.008600008461659682)],
#  2: [('health', 0.02009079941115313),
#   ('alcohol', 0.015297453360695792),
#   ('tb', 0.014851608370689112),
#   ('covid19', 0.011265778298841345),
#   ('countries', 0.011132889846350188),
#   ('2020', 0.010566297206339257),
#   ('virus', 0.010277028464820755),
#   ('global', 0.00872362347600258),
#   ('pda1', 0.008555433951112829),
#   ('disease', 0.008181219454550335)],
#  3: [('is', 0.011969798220473615),
#   ('security', 0.01154828647876164),
#   ('has', 0.010414420882959454),
#   ('us', 0.009946829484398513),
#   ('government', 0.008597464198114866),
#   ('are', 0.007990109133827158),
#   ('political', 0.007563326525484806),
#   ('forces', 0.007560214061567433),
#   ('afghan', 0.007362287688562322),
#   ('iraq', 0.0070481896284589705)],
#  4: [('roma', 0.018679130782749822),
#   ('social', 0.010839769057791474),
#   ('muslim', 0.010243109294992407),
#   ('eu', 0.010150873933973164),
#   ('their', 0.01012743240581683),
#   ('migration', 0.009107509857827083),
#   ('muslims', 0.008758442033508649),
#   ('be', 0.008548128028695678),
#   ('were', 0.008394135885689493),
#   ('programme', 0.008249819137540481)],
#  5: [('de', 0.07327473316216698),
#   ('la', 0.04740852959997394),
#   ('el', 0.036636117155949645),
#   ('los', 0.025708077206841134),
#   ('denver', 0.021279776703218456),
#   ('por', 0.01837777588074744),
#   ('las', 0.016304039799162975),
#   ('colorado', 0.015890277815474578),
#   ('una', 0.01405810430475464),
#   ('nueva', 0.008217118108660534)],
#  6: [('us', 0.013825833567369727),
#   ('states', 0.012073449820180831),
#   ('nuclear', 0.011853827762897737),
#   ('united', 0.010536107374685627),
#   ('security', 0.00955522374520431),
#   ('space', 0.009421949599685096),
#   ('military', 0.008850551573449049),
#   ('has', 0.008111495542598147),
#   ('defense', 0.0077082960201212206),
#   ('at', 0.007447843247794084)],
#  7: [('black', 0.028226710947434983),
#   ('women', 0.026488835102519172),
#   ('percent', 0.02248439474510844),
#   ('health', 0.01789140479675464),
#   ('care', 0.016569940260115493),
#   ('medicaid', 0.016399778370514442),
#   ('states', 0.01582663597023201),
#   ('coverage', 0.015085178766680137),
#   ('insurance', 0.009668881678396793),
#   ('medicare', 0.00898707065720119)],
#  8: [('pharmaceutical', 0.025740805456511175),
#   ('drugs', 0.022930673573066856),
#   ('patent', 0.02072925879417809),
#   ('drug', 0.01928746929794297),
#   ('medicines', 0.014878231431663377),
#   ('trips', 0.012207923241667924),
#   ('health', 0.011041552635619904),
#   ('canada', 0.009921441435825448),
#   ('products', 0.009830606564364242),
#   ('bangladesh', 0.009161167682554169)],
#  9: [('ai', 0.02539512031830254),
#   ('nuclear', 0.02001939172534217),
#   ('cyber', 0.01684442138716087),
#   ('systems', 0.013884599116670164),
#   ('data', 0.010947648446319614),
#   ('technology', 0.010143955424459979),
#   ('intelligence', 0.009734865487108916),
#   ('information', 0.009713647561228155),
#   ('security', 0.009360183988611302),
#   ('cybersecurity', 0.009182264497429938)],
#  10: [('health', 0.061367197949461584),
#   ('services', 0.016516699179221096),
#   ('hospitals', 0.014633823946305417),
#   ('medical', 0.013265831466083903),
#   ('system', 0.01285107762067911),
#   ('government', 0.012361920855740088),
#   ('moh', 0.011040796073016028),
#   ('hospital', 0.009962661210578911),
#   ('facilities', 0.008309722721622274),
#   ('healthcare', 0.008128855146735859)],
#  11: [('health', 0.024991859047116035),
#   ('data', 0.01968531478474652),
#   ('healthcare', 0.019125587343940334),
#   ('information', 0.013499056898879393),
#   ('diffusion', 0.011193945725957456),
#   ('anc', 0.010810426381968781),
#   ('reuse', 0.01066839001481271),
#   ('digital', 0.010616680391653983),
#   ('expenditures', 0.010148610890163065),
#   ('meps', 0.009639068685090924)],
#  12: [('medicine', 0.024559951130803486),
#   ('medical', 0.023860294517782016),
#   ('journal', 0.016556171827207908),
#   ('ethics', 0.01545970439216683),
#   ('patients', 0.013674679270775869),
#   ('bioethics', 0.01151649049332792),
#   ('folklore', 0.011401110969950464),
#   ('health', 0.011249216439732682),
#   ('research', 0.009828097823219658),
#   ('clinical', 0.009107801943708856)],
#  13: [('urban', 0.01808484672526339),
#   ('rural', 0.012618877675716518),
#   ('transport', 0.012460669769145831),
#   ('development', 0.011164232561943386),
#   ('land', 0.01009943768292932),
#   ('china', 0.009372707049964577),
#   ('cities', 0.008914899033520595),
#   ('city', 0.008908785881906895),
#   ('areas', 0.00820985589276237),
#   ('transportation', 0.007853122953300406)],
#  14: [('veterans', 0.026937235581769265),
#   ('va', 0.0175247043819841),
#   ('military', 0.015784465189070084),
#   ('health', 0.012157473881783107),
#   ('trauma', 0.011728130475649518),
#   ('mental', 0.011176043589542738),
#   ('medical', 0.008964487537622754),
#   ('services', 0.008873920808010888),
#   ('dod', 0.008513045526013445),
#   ('service', 0.008373386994898941)],
#  15: [('eu', 0.03270506565268029),
#   ('european', 0.025678210044455974),
#   ('europe', 0.017837433573208057),
#   ('russia', 0.01623024565056875),
#   ('security', 0.012501838492079097),
#   ('cooperation', 0.011470362445958142),
#   ('russian', 0.010423097794324817),
#   ('arctic', 0.009525155286772618),
#   ('nato', 0.009012813182412682),
#   ('political', 0.00836181080600429)],
#  16: [('corruption', 0.03610090480544358),
#   ('transparency', 0.018892722907762553),
#   ('anticorruption', 0.017511261364051126),
#   ('data', 0.011842371055012471),
#   ('international', 0.011491866815335728),
#   ('public', 0.011082145034590358),
#   ('government', 0.0105537362879716),
#   ('illicit', 0.00982583299142501),
#   ('acc', 0.00969657584440417),
#   ('honduras', 0.008316752633853137)],
#  17: [('china', 0.02710583810750974),
#   ('us', 0.01555818396252349),
#   ('economic', 0.014220327901022185),
#   ('chinese', 0.012063910429738195),
#   ('chinas', 0.011519765069519869),
#   ('military', 0.010298471368112292),
#   ('asia', 0.009858255148165398),
#   ('taiwan', 0.009815167142758817),
#   ('countries', 0.008939919697207139),
#   ('cooperation', 0.008855309488679217)],
#  18: [('sars', 0.015367253576819312),
#   ('muslim', 0.012855284866367316),
#   ('be', 0.011950855054467609),
#   ('with', 0.011923587912899807),
#   ('muslims', 0.010525055734052989),
#   ('education', 0.010010690706577953),
#   ('their', 0.008672910806796571),
#   ('medical', 0.00767269880407504),
#   ('training', 0.007558472071260626),
#   ('health', 0.007478586140530711)],
#  19: [('tax', 0.06487501905992256),
#   ('property', 0.02836806828311427),
#   ('valuation', 0.015014868149293528),
#   ('value', 0.012544909456449226),
#   ('taxpayer', 0.012214171248101537),
#   ('government', 0.011041439451862567),
#   ('taxes', 0.009757975568783469),
#   ('inheritance', 0.009172323755110278),
#   ('5g', 0.0091497979009755),
#   ('land', 0.008827229399771316)],
#  20: [('education', 0.02280607493256184),
#   ('learning', 0.022098667536174683),
#   ('research', 0.022074027114362214),
#   ('dual', 0.018339193604335422),
#   ('university', 0.01388358909883653),
#   ('universities', 0.013602723602122302),
#   ('study', 0.01294377852995826),
#   ('science', 0.012674589413949411),
#   ('students', 0.011599953145087048),
#   ('programs', 0.01134509434686888)],
#  21: [('brazil', 0.013594138993925767),
#   ('health', 0.012341010030327556),
#   ('global', 0.012087440311443955),
#   ('amazon', 0.011028161916870442),
#   ('countries', 0.010405190526095629),
#   ('region', 0.009930144920691055),
#   ('latin', 0.009356208653033007),
#   ('united', 0.008917173943386295),
#   ('states', 0.008488983241572441),
#   ('economic', 0.008304137616027713)],
#  22: [('programs', 0.01932502916850646),
#   ('tech', 0.018228186215187347),
#   ('program', 0.01739019737435074),
#   ('york', 0.01638003893832168),
#   ('businesses', 0.016089080374710983),
#   ('workforce', 0.01530240260639134),
#   ('students', 0.013355481849374838),
#   ('citys', 0.011306554345308006),
#   ('training', 0.011117471832020586),
#   ('jobs', 0.009965782846015582)],
#  23: [('africa', 0.029681500096582946),
#   ('african', 0.026303048373726656),
#   ('south', 0.013840236328539783),
#   ('mozambique', 0.012418703124574973),
#   ('africas', 0.009878708325039379),
#   ('economic', 0.00925280932164648),
#   ('political', 0.00791035883676041),
#   ('development', 0.007556665135026703),
#   ('anc', 0.007373127793878331),
#   ('policy', 0.007273147256484223)],
#  24: [('media', 0.022884507699456717),
#   ('australian', 0.016245064442800473),
#   ('crime', 0.013099931126093319),
#   ('asylum', 0.012165337439351075),
#   ('2012', 0.01191165560246375),
#   ('2011', 0.009564649949108116),
#   ('university', 0.009539966488428487),
#   ('social', 0.008956810671150952),
#   ('participatory', 0.008860162123243759),
#   ('australia', 0.008707811900477785)],
#  25: [('chinese', 0.027233847136361438),
#   ('china', 0.02277667282978261),
#   ('tibetan', 0.020152455132760146),
#   ('dalai', 0.020139959600687235),
#   ('chinas', 0.01805298922865808),
#   ('tibet', 0.017827131712776882),
#   ('hong', 0.017398197188578948),
#   ('lama', 0.015213530605803433),
#   ('foreign', 0.010103825351980967),
#   ('beijing', 0.008980202227329684)]}

# %%
freq
# Out:
#     Topic  Count                                            Name
# 0      -1    336                               -1_on_with_to_are
# 1       0    150                 0_energy_climate_in_development
# 2       1    143                              1_women_her_she_we
# 3       2    103                     2_health_alcohol_tb_covid19
# 4       3     88                            3_is_security_has_us
# 5       4     60                         4_roma_social_muslim_eu
# 6       5     53                                  5_de_la_el_los
# 7       6     36                      6_us_states_nuclear_united
# 8       7     35                    7_black_women_percent_health
# 9       8     33              8_pharmaceutical_drugs_patent_drug
# 10      9     30                      9_ai_nuclear_cyber_systems
# 11     10     30            10_health_services_hospitals_medical
# 12     11     29           11_health_data_healthcare_information
# 13     12     27              12_medicine_medical_journal_ethics
# 14     13     26            13_urban_rural_transport_development
# 15     14     26                  14_veterans_va_military_health
# 16     15     24                    15_eu_european_europe_russia
# 17     16     23  16_corruption_transparency_anticorruption_data
# 18     17     19                    17_china_us_economic_chinese
# 19     18     19                          18_sars_muslim_be_with
# 20     19     18                 19_tax_property_valuation_value
# 21     20     17             20_education_learning_research_dual
# 22     21     16                  21_brazil_health_global_amazon
# 23     22     16                   22_programs_tech_program_york
# 24     23     16              23_africa_african_south_mozambique
# 25     24     15                24_media_australian_crime_asylum
# 26     25     13                  25_chinese_china_tibetan_dalai

# %%
topic_model.visualize_barchart(top_n_topics=10, height=2000)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="c53ed09a-237a-4e3d-bf05-176695742c62" class="plotly-graph-div" style="height:2000px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c53ed09a-237a-4e3d-bf05-176695742c62")) {                    Plotly.newPlot(                        "c53ed09a-237a-4e3d-bf05-176695742c62",                        [{"orientation": "h", "type": "bar", "x": [0.00818732607612603, 0.010035159333002981, 0.011541592668483043, 0.012081588975836777, 0.014548327411753591], "xaxis": "x", "y": ["water  ", "development  ", "climate  ", "energy  ", "for  "], "yaxis": "y"}, {"orientation": "h", "type": "bar", "x": [0.011203047231985626, 0.012292010987515407, 0.012964671140776662, 0.015481847399923707, 0.018028734308466646], "xaxis": "x2", "y": ["with  ", "we  ", "she  ", "her  ", "women  "], "yaxis": "y2"}, {"orientation": "h", "type": "bar", "x": [0.010396551369365969, 0.010454759194090082, 0.013062542306171909, 0.013478045497774389, 0.019542348646556077], "xaxis": "x3", "y": ["countries  ", "covid19  ", "tb  ", "alcohol  ", "health  "], "yaxis": "y3"}, {"orientation": "h", "type": "bar", "x": [0.008324200632328927, 0.008526385852203925, 0.010407918534130645, 0.01148877412177045, 0.012037659209625975], "xaxis": "x4", "y": ["have  ", "government  ", "has  ", "security  ", "is  "], "yaxis": "y4"}, {"orientation": "h", "type": "bar", "x": [0.021279776703218456, 0.025708077206841134, 0.036636117155949645, 0.04740852959997394, 0.07327473316216698], "xaxis": "x5", "y": ["denver  ", "los  ", "el  ", "la  ", "de  "], "yaxis": "y5"}, {"orientation": "h", "type": "bar", "x": [0.009790760229212344, 0.01014626873427977, 0.010623392462260565, 0.011877882741900377, 0.012638851752731347], "xaxis": "x6", "y": ["at  ", "students  ", "science  ", "film  ", "programs  "], "yaxis": "y6"}, {"orientation": "h", "type": "bar", "x": [0.010710178236265744, 0.011389120043929007, 0.012153859822853105, 0.012536533477062113, 0.02289706660736074], "xaxis": "x7", "y": ["muslims  ", "migration  ", "eu  ", "muslim  ", "roma  "], "yaxis": "y7"}, {"orientation": "h", "type": "bar", "x": [0.01580519037237965, 0.01693260518105413, 0.01789077980301292, 0.018492263899321786, 0.022038364991086204], "xaxis": "x8", "y": ["states  ", "medicaid  ", "health  ", "care  ", "percent  "], "yaxis": "y8"}, {"orientation": "h", "type": "bar", "x": [0.014558098734616066, 0.01880109674942769, 0.02018280764853016, 0.021724041077558383, 0.025212036623322134], "xaxis": "x9", "y": ["medicines  ", "drug  ", "patent  ", "drugs  ", "pharmaceutical  "], "yaxis": "y9"}, {"orientation": "h", "type": "bar", "x": [0.01132562103295404, 0.011968860923594477, 0.014321509054448745, 0.018581084046450865, 0.04008165772426027], "xaxis": "x10", "y": ["safety  ", "workload  ", "healthcare  ", "data  ", "trauma  "], "yaxis": "y10"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "Topic 0", "x": 0.11666666666666665, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Topic 1", "x": 0.49999999999999994, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Topic 2", "x": 0.8833333333333333, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Topic 3", "x": 0.11666666666666665, "xanchor": "center", "xref": "paper", "y": 0.7124999999999999, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Topic 4", "x": 0.49999999999999994, "xanchor": "center", "xref": "paper", "y": 0.7124999999999999, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "sh ...

# %%
topic_model.visualize_topics(top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="16acf5f8-187d-4e6e-9127-5d8d2fa18bf6" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16acf5f8-187d-4e6e-9127-5d8d2fa18bf6")) {                    Plotly.newPlot(                        "16acf5f8-187d-4e6e-9127-5d8d2fa18bf6",                        [{"customdata": [[-9.291816711425781, -2.6086089611053467, 1, "women | her | she | we | with", 144], [21.773488998413086, 2.9659550189971924, 2, "health | alcohol | tb | covid19 | countries", 117], [-8.712869644165039, 2.747807264328003, 3, "is | security | has | government | have", 90], [-8.990068435668945, -2.1335089206695557, 4, "de | la | el | los | denver", 53], [-9.779553413391113, 0.49055811762809753, 5, "programs | film | science | students | at", 48], [-8.770381927490234, 3.8094801902770996, 6, "roma | muslim | eu | migration | muslims", 41], [-9.329206466674805, -0.597391664981842, 7, "percent | care | health | medicaid | states", 37], [-8.05652904510498, 2.030585289001465, 8, "pharmaceutical | drugs | patent | drug | medicines", 35], [-9.50684642791748, -0.4462844431400299, 9, "trauma | data | healthcare | workload | safety", 32], [-7.270690441131592, 2.685344934463501, 10, "us | nuclear | states | united | space", 32], [22.122156143188477, 3.37089204788208, 11, "urban | rural | transport | development | china", 29], [-8.0741605758667, 3.2572734355926514, 12, "ai | nuclear | cyber | systems | technology", 29], [21.881494522094727, 3.076040744781494, 13, "health | services | hospitals | medical | government", 27], [-7.525946140289307, 1.9479392766952515, 14, "corruption | transparency | anticorruption | data | international", 24], [-9.340431213378906, -2.1371002197265625, 15, "veterans | va | health | mental | veteran", 23], [-8.157161712646484, 2.090430498123169, 16, "sars | on | are | muslim | be", 22], [-9.811410903930664, -0.19292502105236053, 17, "medicine | journal | patients | folklore | medical", 20], [-8.239992141723633, 1.573058843612671, 18, "eu | european | europe | russia | states", 20], [-10.087526321411133, 0.21207593381404877, 19, "media | crime | australian | video | public", 17]], "hovertemplate": "<b>Topic %{customdata[2]}</b><br>Words: %{customdata[3]}<br>Size: %{customdata[4]}", "legendgroup": "", "marker": {"color": "#B0BEC5", "line": {"color": "DarkSlateGrey", "width": 2}, "size": [144, 117, 90, 53, 48, 41, 37, 35, 32, 32, 29, 29, 27, 24, 23, 22, 20, 20, 17], "sizemode": "area", "sizeref": 0.09, "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [-9.291816711425781, 21.773488998413086, -8.712869644165039, -8.990068435668945, -9.779553413391113, -8.770381927490234, -9.329206466674805, -8.05652904510498, -9.50684642791748, -7.270690441131592, 22.122156143188477, -8.0741605758667, 21.881494522094727, -7.525946140289307, -9.340431213378906, -8.157161712646484, -9.811410903930664, -8.239992141723633, -10.087526321411133], "xaxis": "x", "y": [-2.6086089611053467, 2.9659550189971924, 2.747807264328003, -2.1335089206695557, 0.49055811762809753, 3.8094801902770996, -0.597391664981842, 2.030585289001465, -0.4462844431400299, 2.685344934463501, 3.37089204788208, 3.2572734355926514, 3.076040744781494, 1.9479392766952515, -2.1371002197265625, 2.090430498123169, -0.19292502105236053, 1.573058843612671, 0.21207593381404877], "yaxis": "y"}],                        {"annotations": [{"showarrow": false, "text": "D1", "x": -11.600655269622802, "y": 0.6905009567737579, "yshift": 10}, {"showarrow": false, "text": "D2", "x": 6.919912147521973, "xshift": 10, "y": 4.380902218818664}], "height": 650, "hoverlabel": {"bgcolor": "white", "font": {"family": "Rockwell", "size": 16}}, "legend": {"itemsizing": "constant", " ...

# %%
topic_model.visualize_hierarchy(top_n_topics=50, width=800)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="b8f3ecb3-8984-41d7-9ca4-791b939772b2" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8f3ecb3-8984-41d7-9ca4-791b939772b2")) {                    Plotly.newPlot(                        "b8f3ecb3-8984-41d7-9ca4-791b939772b2",                        [{"hoverinfo": "text", "marker": {"color": "rgb(61,153,112)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.47330695390444427, 0.47330695390444427, 0.0], "xaxis": "x", "y": [-5.0, -5.0, -15.0, -15.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(255,65,54)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.9286720146460067, 0.9286720146460067, 0.0], "xaxis": "x", "y": [-25.0, -25.0, -35.0, -35.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(0,116,217)"}, "mode": "lines", "type": "scatter", "x": [0.47330695390444427, 1.2873963363114287, 1.2873963363114287, 0.9286720146460067], "xaxis": "x", "y": [-10.0, -10.0, -30.0, -30.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(35,205,205)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.29131603834176234, 0.29131603834176234, 0.0], "xaxis": "x", "y": [-75.0, -75.0, -85.0, -85.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(35,205,205)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.4636351736312278, 0.4636351736312278, 0.29131603834176234], "xaxis": "x", "y": [-65.0, -65.0, -80.0, -80.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(35,205,205)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.46695461073754907, 0.46695461073754907, 0.0], "xaxis": "x", "y": [-95.0, -95.0, -105.0, -105.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(35,205,205)"}, "mode": "lines", "type": "scatter", "x": [0.4636351736312278, 0.5343244317386928, 0.5343244317386928, 0.46695461073754907], "xaxis": "x", "y": [-72.5, -72.5, -100.0, -100.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(35,205,205)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.6286730753528407, 0.6286730753528407, 0.5343244317386928], "xaxis": "x", "y": [-55.0, -55.0, -86.25, -86.25], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(35,205,205)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.7004107250319579, 0.7004107250319579, 0.6286730753528407], "xaxis": "x", "y": [-45.0, -45.0, -70.625, -70.625], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(133,20,75)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.464492954396245, 0.464492954396245, 0.0], "xaxis": "x", "y": [-115.0, -115.0, -125.0, -125.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(133,20,75)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.4730039065980349, 0.4730039065980349, 0.0], "xaxis": "x", "y": [-135.0, -135.0, -145.0, -145.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(133,20,75)"}, "mode": "lines", "type": "scatter", "x": [0.464492954396245, 0.6041315722984467, 0.6041315722984467, 0.4730039065980349], "xaxis": "x", "y": [-120.0, -120.0, -140.0, -140.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(255,220,0)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.43631605643189436, 0.43631605643189436, 0.0], "xaxis": "x", "y": [-165.0, -165.0, -175.0, -175.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(255,220,0)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.6066639656836199, 0.6066639656836199, 0.43631605643189436], "xaxis": "x", "y": [-155.0, -155.0, -170.0, -170.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(255,220,0)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.3854649656040985, 0.3854649656040985, 0.0], "xaxis": "x", "y": [-185.0, -185.0, -195.0, -195.0] ...

# %%
topics_over_time = topic_model.topics_over_time(data.fullText,
                                                topics,
                                                data.datePublished,
                                                nr_bins=70)
# Out:
# 36it [05:13,  8.70s/it]

# %%
# model.visualize_topics_over_time(topics_over_time, topics=[9, 10, 72, 83, 87, 91])
topic_model.visualize_topics_over_time(topics_over_time)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="f2b4e226-3a89-40ff-aeb5-e1e7277beb58" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2b4e226-3a89-40ff-aeb5-e1e7277beb58")) {                    Plotly.newPlot(                        "f2b4e226-3a89-40ff-aeb5-e1e7277beb58",                        [{"hoverinfo": "text", "hovertext": ["<b>Topic 1</b><br>Words: at, women, her, we, be", "<b>Topic 1</b><br>Words: at, for, her, women, be", "<b>Topic 1</b><br>Words: was, at, women, her, he", "<b>Topic 1</b><br>Words: at, her, he, she, with", "<b>Topic 1</b><br>Words: at, he, her, women, with", "<b>Topic 1</b><br>Words: women, was, we, her, for", "<b>Topic 1</b><br>Words: women, we, her, at, with", "<b>Topic 1</b><br>Words: women, at, we, was, her", "<b>Topic 1</b><br>Words: women, we, her, she, my", "<b>Topic 1</b><br>Words: women, her, was, she, art", "<b>Topic 1</b><br>Words: women, we, her, she, with", "<b>Topic 1</b><br>Words: women, her, we, she, womens", "<b>Topic 1</b><br>Words: women, her, we, for, she", "<b>Topic 1</b><br>Words: she, her, women, you, with", "<b>Topic 1</b><br>Words: women, her, she, my, we", "<b>Topic 1</b><br>Words: women, her, she, we, womens", "<b>Topic 1</b><br>Words: women, her, she, for, we", "<b>Topic 1</b><br>Words: women, her, she, we, my", "<b>Topic 1</b><br>Words: her, she, women, my, we", "<b>Topic 1</b><br>Words: women, her, feminist, she, we", "<b>Topic 1</b><br>Words: women, call, was, he, we", "<b>Topic 1</b><br>Words: her, women, she, pb, feminist", "<b>Topic 1</b><br>Words: we, they, with, their, women", "<b>Topic 1</b><br>Words: de, la, los, el, colorado", "<b>Topic 1</b><br>Words: place, writing, placeconscious, her, nebraska", "<b>Topic 1</b><br>Words: discrimination, systemic, inequality, gender, women", "<b>Topic 1</b><br>Words: women, media, writing, womens, birth", "<b>Topic 1</b><br>Words: she, her, my, he, his", "<b>Topic 1</b><br>Words: we, by, with, her, their", "<b>Topic 1</b><br>Words: women, for, we, her, with", "<b>Topic 1</b><br>Words: we, about, so, it, copyright", "<b>Topic 1</b><br>Words: women, for, to, her, our"], "marker": {"color": "#E69F00"}, "mode": "lines", "name": "1_women_her_she_we", "type": "scatter", "x": ["1901-11-01T09:33:07.200000", "1903-08-29T21:15:25.714285", "1905-05-13T18:30:51.428571", "1913-11-22T04:48:00", "1925-10-30T09:36:00", "1970-03-03T10:17:08.571428", "1971-11-16T07:32:34.285714", "1973-07-31T04:48:00", "1975-04-15T02:03:25.714285", "1976-12-27T23:18:51.428571", "1978-09-11T20:34:17.142857", "1980-05-26T17:49:42.857142", "1982-02-08T15:05:08.571428", "1983-10-24T12:20:34.285714", "1985-07-08T09:36:00", "1987-03-23T06:51:25.714285", "1988-12-05T04:06:51.428571", "1990-08-20T01:22:17.142857", "1992-05-03T22:37:42.857142", "1994-01-16T19:53:08.571428", "1995-10-01T17:08:34.285713", "1997-06-15T14:24:00", "2000-11-12T08:54:51.428571", "2002-07-28T06:10:17.142857", "2005-12-25T00:41:08.571428", "2007-09-08T21:56:34.285713", "2009-05-23T19:12:00", "2011-02-05T16:27:25.714285", "2012-10-20T13:42:51.428571", "2014-07-05T10:58:17.142857", "2016-03-19T08:13:42.857142", "2017-12-02T05:29:08.571428"], "y": [1, 1, 4, 2, 1, 3, 10, 5, 5, 6, 5, 7, 4, 2, 3, 13, 9, 11, 5, 6, 4, 3, 3, 1, 1, 1, 2, 3, 1, 9, 1, 11]}, {"hoverinfo": "text", "hovertext": ["<b>Topic 14</b><br>Words: black, we, veterans, muhammad, are", "<b>Topic 14</b><br>Words: vets, va, veterans, we, vvaw", "<b>Topic 14</b><br>Words: veterans, vets, vvaw, we, their", "<b>Topic 14</b><br>Words: veterans, we, are, care, military", "<b>Topic 14</b><br>Words: de, la, veterans, los, el", "<b>Topic 14</b><br>Words: mental, veterans, va, tbi, treatment", "<b>Topic 14</b><br>Words: medical, afms, civilian, military, physicians", "<b>Topic 14</b><br>Words: veter ...

# %%
topics_over_time['time_int'] = topics_over_time.Timestamp.apply(lambda x: int(x.timestamp()))

# %%
topic_counts = topics_over_time.Topic.value_counts().reset_index()
topic_counts
# Out:
#     index  Topic
# 0       1     32
# 1      -1     17
# 2       5     14
# 3       0     12
# 4       4     12
# 5       2     12
# 6      14     12
# 7       3     10
# 8       7     10
# 9      11      9
# 10      6      9
# 11      8      9
# 12     10      9
# 13     13      9
# 14     18      9
# 15     24      8
# 16     12      7
# 17     25      7
# 18     15      7
# 19     17      7
# 20     23      7
# 21      9      6
# 22     16      5
# 23     20      5
# 24     21      5
# 25     19      5
# 26     22      4

# %%
def get_regression_slope(topic_num):
    X = topics_over_time.loc[topics_over_time.Topic == topic_num,'time_int'].to_numpy()
    y = topics_over_time.loc[topics_over_time.Topic == topic_num,'Frequency'].to_numpy()
    X = X.reshape(-1, 1)
    y = y.reshape(-1, 1)
    reg = LinearRegression().fit(X, y)
    return reg.coef_[0][0]

# %%
get_topic_names = topics_over_time.loc[:,['Topic', 'Name']].drop_duplicates()
get_topic_names['slope'] = get_topic_names.apply(lambda x: get_regression_slope(x.Topic), axis=1)
get_topic_names = get_topic_names.sort_values('slope', ascending=False)
get_topic_names
# Out:
#      Topic                                         Name         slope
# 38       2                  2_health_alcohol_tb_covid19  5.314534e-08
# 10      -1                            -1_on_with_to_are  5.084408e-08
# 128      9                   9_ai_nuclear_cyber_systems  4.671889e-08
# 152     16  16_corruption_transparency_anticorruptio...  3.158834e-08
# 51       3                         3_is_security_has_us  2.891777e-08
# 16       0              0_energy_climate_in_development  2.292282e-08
# 97      21               21_brazil_health_global_amazon  1.542063e-08
# 134     22                22_programs_tech_program_york  1.194517e-08
# 39       4                      4_roma_social_muslim_eu  9.115770e-09
# 75       6                   6_us_states_nuclear_united  8.051930e-09
# 63      10         10_health_services_hospitals_medical  7.642340e-09
# 56      23           23_africa_african_south_mozambique  7.096577e-09
# 45      17                 17_china_us_economic_chinese  6.544546e-09
# 67      18                       18_sars_muslim_be_with  6.448831e-09
# 44      15                 15_eu_european_europe_russia  6.341678e-09
# 46      19              19_tax_property_valuation_value  4.574603e-09
# 62       8           8_pharmaceutical_drugs_patent_drug  4.495494e-09
# 7        7                 7_black_women_percent_health  3.597650e-09
# 57      25               25_chinese_china_tibetan_dalai  3.288063e-09
# 12      13         13_urban_rural_transport_development  2.238093e-09
# 43      12           12_medicine_medical_journal_ethics  2.135360e-09
# 0        1                           1_women_her_she_we  6.973666e-10
# 5       14               14_veterans_va_military_health  5.568943e-10
# 115     20          20_education_learning_research_dual  5.021993e-10
# 80      24             24_media_australian_crime_asylum  4.184995e-10
# 26       5                               5_de_la_el_los -2.401625e-09
# 54      11        11_health_data_healthcare_information -5.865447e-09

# %%
topics_over_time.loc[topics_over_time.Topic == -1,:]
# Out:
#      Topic  ...    time_int
# 10      -1  ...   166759405
# 27      -1  ...   704932662
# 31      -1  ...   812567314
# 33      -1  ...   866384640
# 36      -1  ...   920201965
# 40      -1  ...   974019291
# 47      -1  ...  1027836617
# 58      -1  ...  1081653942
# 68      -1  ...  1135471268
# 81      -1  ...  1189288594
# 100     -1  ...  1243105920
# 119     -1  ...  1296923245
# 136     -1  ...  1350740571
# 159     -1  ...  1404557897
# 182     -1  ...  1458375222
# 208     -1  ...  1512192548
# 234     -1  ...  1566009874
#
# [17 rows x 6 columns]

# %%
topics_over_time.loc[topics_over_time.Topic == 24,:]
# Out:
#      Topic  ...    time_int
# 80      24  ...  1135471268
# 99      24  ...  1189288594
# 135     24  ...  1296923245
# 157     24  ...  1350740571
# 180     24  ...  1404557897
# 206     24  ...  1458375222
# 232     24  ...  1512192548
# 256     24  ...  1566009874
#
# [8 rows x 6 columns]

# %%
ting = topic_model.get_topics()
ting = pd.DataFrame(ting).T

# %%
ting
# Out:
#                                           0  ...                                       9
# -1               (on, 0.011824509618097969)  ...     (development, 0.006107898383142128)
#  0           (energy, 0.012513402702892142)  ...           (index, 0.006589487418612333)
#  1            (women, 0.018660986364903438)  ...             (our, 0.008600008461659682)
#  2            (health, 0.02009079941115313)  ...         (disease, 0.008181219454550335)
#  3               (is, 0.011969798220473615)  ...           (iraq, 0.0070481896284589705)
#  4             (roma, 0.018679130782749822)  ...       (programme, 0.008249819137540481)
#  5                (de, 0.07327473316216698)  ...           (nueva, 0.008217118108660534)
#  6               (us, 0.013825833567369727)  ...              (at, 0.007447843247794084)
#  7            (black, 0.028226710947434983)  ...         (medicare, 0.00898707065720119)
#  8   (pharmaceutical, 0.025740805456511175)  ...      (bangladesh, 0.009161167682554169)
#  9                (ai, 0.02539512031830254)  ...   (cybersecurity, 0.009182264497429938)
#  10          (health, 0.061367197949461584)  ...      (healthcare, 0.008128855146735859)
#  11          (health, 0.024991859047116035)  ...            (meps, 0.009639068685090924)
#  12        (medicine, 0.024559951130803486)  ...        (clinical, 0.009107801943708856)
#  13            (urban, 0.01808484672526339)  ...  (transportation, 0.007853122953300406)
#  14        (veterans, 0.026937235581769265)  ...         (service, 0.008373386994898941)
#  15               (eu, 0.03270506565268029)  ...        (political, 0.00836181080600429)
#  16       (corruption, 0.03610090480544358)  ...        (honduras, 0.008316752633853137)
#  17            (china, 0.02710583810750974)  ...     (cooperation, 0.008855309488679217)
#  18            (sars, 0.015367253576819312)  ...          (health, 0.007478586140530711)
#  19              (tax, 0.06487501905992256)  ...            (land, 0.008827229399771316)
#  20        (education, 0.02280607493256184)  ...         (programs, 0.01134509434686888)
#  21          (brazil, 0.013594138993925767)  ...        (economic, 0.008304137616027713)
#  22         (programs, 0.01932502916850646)  ...            (jobs, 0.009965782846015582)
#  23          (africa, 0.029681500096582946)  ...          (policy, 0.007273147256484223)
#  24           (media, 0.022884507699456717)  ...       (australia, 0.008707811900477785)
#  25         (chinese, 0.027233847136361438)  ...         (beijing, 0.008980202227329684)
#
# [27 rows x 10 columns]

# %%
ting2 = ting.apply(lambda y: y.apply(lambda x: x[0]))

# %%
ting2.to_csv('20211114_dynamic_topics.csv')

# %%
ting2
# Out:
#                   0             1  ...              8               9
# -1               on          with  ...          their     development
#  0           energy       climate  ...     population           index
#  1            women           her  ...             be             our
#  2           health       alcohol  ...           pda1         disease
#  3               is      security  ...         afghan            iraq
#  4             roma        social  ...           were       programme
#  5               de            la  ...            una           nueva
#  6               us        states  ...        defense              at
#  7            black         women  ...      insurance        medicare
#  8   pharmaceutical         drugs  ...       products      bangladesh
#  9               ai       nuclear  ...       security   cybersecurity
#  10          health      services  ...     facilities      healthcare
#  11          health          data  ...   expenditures            meps
#  12        medicine       medical  ...       research        clinical
#  13           urban         rural  ...          areas  transportation
#  14        veterans            va  ...            dod         service
#  15              eu      european  ...           nato       political
#  16      corruption  transparency  ...            acc        honduras
#  17           china            us  ...      countries     cooperation
#  18            sars        muslim  ...       training          health
#  19             tax      property  ...             5g            land
#  20       education      learning  ...       students        programs
#  21          brazil        health  ...         states        economic
#  22        programs          tech  ...       training            jobs
#  23          africa       african  ...            anc          policy
#  24           media    australian  ...  participatory       australia
#  25         chinese         china  ...        foreign         beijing
#
# [27 rows x 10 columns]
